# %%
import pandas as pd
import os

# %%
diretorio_atual = os.getcwd()
print(diretorio_atual)
# Out:
# C:\Users\Pichau\Pandas_VAROS

# %%
dados_petrobras = pd.read_excel("dados\Mundo8dados_petro.xlsx")
dados_petrobras
# Out:
#              Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                Curso:  codigo.py        NaN        NaN        NaN
# 1                  Aula    Mundo 8        NaN        NaN        NaN
# 2                   NaN        NaN        NaN        NaN        NaN
# 3                   NaN        NaN        NaN        NaN        NaN
# 4                   NaN        NaN        NaN        NaN        NaN
# ..                  ...        ...        ...        ...        ...
# 86  2022-05-20 00:00:00  25.450721   1.931519      34.83   25.27535
# 87  2022-05-19 00:00:00  24.968451   1.696429      34.17  24.493488
# 88  2022-05-18 00:00:00  24.551945  -1.639344       33.6  24.975758
# 89  2022-05-17 00:00:00  24.961144  -1.300202      34.16  25.574943
# 90  2022-05-16 00:00:00  25.289965   0.992121      34.61  25.026908
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7   Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0         NaN        NaN        NaN          NaN        NaN         NaN
# ...

# %%
dados_petrobras = pd.read_excel("dados\Mundo8dados_petro.xlsx", skiprows=6)
dados_petrobras
# Out:
#          Data Fech Ajustado Variação(%) Fech Histórico Abertura Ajustado  \
# 0  2022-09-13            nd          nd             nd                nd
# 1  2022-09-12         31.58   -0.660585          31.58             32.15
# 2  2022-09-09         31.79   -0.031447          31.79             32.49
# 3  2022-09-08          31.8   -0.934579           31.8             32.31
# 4  2022-09-06          32.1   -3.690369           32.1             32.27
# ..        ...           ...         ...            ...               ...
# 80 2022-05-20     25.450721    1.931519          34.83          25.27535
# 81 2022-05-19     24.968451    1.696429          34.17         24.493488
# 82 2022-05-18     24.551945   -1.639344           33.6         24.975758
# 83 2022-05-17     24.961144   -1.300202          34.16         25.574943
# 84 2022-05-16     25.289965    0.992121          34.61         25.026908
#
#    Mín Ajustado Médio Ajustado Máx Ajustado  Vol (MM R$) Negócios Fator   Tipo
# ...

# %%
dados_petrobras = pd.read_excel("dados\Mundo8dados_petro.xlsx", skiprows = 6, index_col = "Data")
dados_petrobras
# Out:
#            Fech Ajustado Variação(%) Fech Histórico Abertura Ajustado  \
# Data
# 2022-09-13            nd          nd             nd                nd
# 2022-09-12         31.58   -0.660585          31.58             32.15
# 2022-09-09         31.79   -0.031447          31.79             32.49
# 2022-09-08          31.8   -0.934579           31.8             32.31
# 2022-09-06          32.1   -3.690369           32.1             32.27
# ...                  ...         ...            ...               ...
# 2022-05-20     25.450721    1.931519          34.83          25.27535
# 2022-05-19     24.968451    1.696429          34.17         24.493488
# 2022-05-18     24.551945   -1.639344           33.6         24.975758
# 2022-05-17     24.961144   -1.300202          34.16         25.574943
# 2022-05-16     25.289965    0.992121          34.61         25.026908
#
#            Mín Ajustado Médio Ajustado Máx Ajustado  Vol (MM R$) Negócios  \
# Data
# ...

# %%
dados_petrobras.dropna()
# Out:
#            Fech Ajustado Variação(%) Fech Histórico Abertura Ajustado  \
# Data
# 2022-09-13            nd          nd             nd                nd
# 2022-09-12         31.58   -0.660585          31.58             32.15
# 2022-09-09         31.79   -0.031447          31.79             32.49
# 2022-09-08          31.8   -0.934579           31.8             32.31
# 2022-09-06          32.1   -3.690369           32.1             32.27
# ...                  ...         ...            ...               ...
# 2022-05-20     25.450721    1.931519          34.83          25.27535
# 2022-05-19     24.968451    1.696429          34.17         24.493488
# 2022-05-18     24.551945   -1.639344           33.6         24.975758
# 2022-05-17     24.961144   -1.300202          34.16         25.574943
# 2022-05-16     25.289965    0.992121          34.61         25.026908
#
#            Mín Ajustado Médio Ajustado Máx Ajustado  Vol (MM R$) Negócios  \
# Data
# ...

# %%
dados_petrobras = pd.read_excel("dados\Mundo8dados_petro.xlsx",skiprows=6, index_col = "Data", na_values="nd")

dados_petrobras
# Out:
#             Fech Ajustado  Variação(%)  Fech Histórico  Abertura Ajustado  \
# Data
# 2022-09-13            NaN          NaN             NaN                NaN
# 2022-09-12      31.580000    -0.660585           31.58          32.150000
# 2022-09-09      31.790000    -0.031447           31.79          32.490000
# 2022-09-08      31.800000    -0.934579           31.80          32.310000
# 2022-09-06      32.100000    -3.690369           32.10          32.270000
# ...                   ...          ...             ...                ...
# 2022-05-20      25.450721     1.931519           34.83          25.275350
# 2022-05-19      24.968451     1.696429           34.17          24.493488
# 2022-05-18      24.551945    -1.639344           33.60          24.975758
# 2022-05-17      24.961144    -1.300202           34.16          25.574943
# 2022-05-16      25.289965     0.992121           34.61          25.026908
#
# ...

# %%
dados_petrobras.dropna()
# Out:
#             Fech Ajustado  Variação(%)  Fech Histórico  Abertura Ajustado  \
# Data
# 2022-09-12      31.580000    -0.660585           31.58          32.150000
# 2022-09-09      31.790000    -0.031447           31.79          32.490000
# 2022-09-08      31.800000    -0.934579           31.80          32.310000
# 2022-09-06      32.100000    -3.690369           32.10          32.270000
# 2022-09-05      33.330000    -0.269300           33.33          33.850000
# ...                   ...          ...             ...                ...
# 2022-05-20      25.450721     1.931519           34.83          25.275350
# 2022-05-19      24.968451     1.696429           34.17          24.493488
# 2022-05-18      24.551945    -1.639344           33.60          24.975758
# 2022-05-17      24.961144    -1.300202           34.16          25.574943
# 2022-05-16      25.289965     0.992121           34.61          25.026908
#
# ...

# %%
dados_petrobras = pd.read_excel("dados\Mundo8dados_petro.xlsx", skiprows=6, index_col = 'Data', na_values = "nd", decimal=",")
dados_petrobras.dropna()
# Out:
#             Fech Ajustado  Variação(%)  Fech Histórico  Abertura Ajustado  \
# Data
# 2022-09-12      31.580000    -0.660585           31.58          32.150000
# 2022-09-09      31.790000    -0.031447           31.79          32.490000
# 2022-09-08      31.800000    -0.934579           31.80          32.310000
# 2022-09-06      32.100000    -3.690369           32.10          32.270000
# 2022-09-05      33.330000    -0.269300           33.33          33.850000
# ...                   ...          ...             ...                ...
# 2022-05-20      25.450721     1.931519           34.83          25.275350
# 2022-05-19      24.968451     1.696429           34.17          24.493488
# 2022-05-18      24.551945    -1.639344           33.60          24.975758
# 2022-05-17      24.961144    -1.300202           34.16          25.574943
# 2022-05-16      25.289965     0.992121           34.61          25.026908
#
# ...

# %%
dados_petrobras = pd.read_excel("dados\Mundo8dados_petro.xlsx", skiprows=6, index_col = 'Data', na_values='nd', decimal = ',', usecols = ['Data','Fech Ajustado', 'Vol (MM R$)'])
dados_petrobras.dropna()
# Out:
#             Fech Ajustado  Vol (MM R$)
# Data
# 2022-09-12      31.580000  2267.814565
# 2022-09-09      31.790000  1588.898586
# 2022-09-08      31.800000  2011.363072
# 2022-09-06      32.100000  3555.963567
# 2022-09-05      33.330000  2536.813661
# ...                   ...          ...
# 2022-05-20      25.450721  2697.429409
# 2022-05-19      24.968451  2165.226242
# 2022-05-18      24.551945  2730.939150
# 2022-05-17      24.961144  3107.951524
# 2022-05-16      25.289965  3184.449800
#
# [84 rows x 2 columns]

# %%
# Como transformar dados para excel

dados_petrobras.to_excel('dados\Mundo8teste_petro.xlsx')

# %% [markdown]
# # Exercícios
#
# - Exercício 57: Leia a planilha disponibilizada na pasta dados 'Mundo8excercicio_receita_petro.xlsx', que contém a receita da Petrobras desde 2008. Mantenha apenas as colunas "Receita Liquída" e "Convenção". Transforme a coluna de Data em índice.

# %%
df = pd.read_excel("dados\Mundo8exercicio_receita_petro.xlsx", skiprows=4, index_col = 'Data', usecols = ['Data','Receita Líquida 12 meses Consolidado Milhões', 'Convenção'] )
df
# Out:
#             Receita Líquida 12 meses Consolidado Milhões   Convenção
# Data
# 2022-06-30                                    568385.000        IFRS
# 2022-03-31                                    508135.000        IFRS
# 2021-12-31                                    452668.000        IFRS
# 2021-09-30                                    393450.000        IFRS
# 2021-06-30                                    342586.000        IFRS
# 2021-03-31                                    282774.000        IFRS
# 2020-12-31                                    272069.000        IFRS
# 2020-09-30                                    269725.000        IFRS
# 2020-06-30                                    276046.000        IFRS
# 2020-03-31                                    297715.000        IFRS
# 2019-12-31                                    302245.000        IFRS
# 2019-09-30                                    322337.000        IFRS
# ...
