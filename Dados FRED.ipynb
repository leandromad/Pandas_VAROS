# %%
from pandas_datareader import data as pdr
import pandas as pd
from datetime import datetime

# %%
dados_fred = pdr.get_data_fred("GDP", start = '1947-01-01', end = datetime.now())
dados_fred
# Out:
#                   GDP
# DATE
# 1947-01-01    243.164
# 1947-04-01    245.968
# 1947-07-01    249.585
# 1947-10-01    259.745
# 1948-01-01    265.742
# ...               ...
# 2021-07-01  23550.420
# 2021-10-01  24349.121
# 2022-01-01  24740.480
# 2022-04-01  25248.476
# 2022-07-01  25723.941
#
# [303 rows x 1 columns]

# %%
dado_faculdade = pdr.get_data_fred("GCT1502US", start = '2006-01-01', end = datetime.now())
dado_faculdade
# Out:
#             GCT1502US
# DATE
# 2006-01-01       27.0
# 2007-01-01       27.5
# 2008-01-01       27.7
# 2009-01-01       27.9
# 2010-01-01       28.2
# 2011-01-01       28.5
# 2012-01-01       29.1

# %%
dado_yeld_3_meses = pdr.get_data_fred("TB3MS", start = '1910-01-01', end = datetime.now())
dado_yeld_3_meses
# Out:
#             TB3MS
# DATE
# 1934-01-01   0.72
# 1934-02-01   0.62
# 1934-03-01   0.24
# 1934-04-01   0.15
# 1934-05-01   0.16
# ...           ...
# 2022-08-01   2.63
# 2022-09-01   3.13
# 2022-10-01   3.72
# 2022-11-01   4.15
# 2022-12-01   4.25
#
# [1068 rows x 1 columns]

# %%
dado_yeld_3_meses.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# # Exercícios
# - Exercício 61: Puxe os dados da inflação americana (CPI) desde o inico da série de dados no FRED.

# %%
dados_inflacao_cpi = pdr.get_data_fred('CPIAUCSL', start = '1947-01-01', end = datetime.now())
dados_inflacao_cpi
# Out:
#             CPIAUCSL
# DATE
# 1947-01-01    21.480
# 1947-02-01    21.620
# 1947-03-01    22.000
# 1947-04-01    22.000
# 1947-05-01    21.950
# ...              ...
# 2022-07-01   295.271
# 2022-08-01   295.620
# 2022-09-01   296.761
# 2022-10-01   298.062
# 2022-11-01   298.349
#
# [911 rows x 1 columns]
